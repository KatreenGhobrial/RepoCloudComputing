# %% [markdown]
# <a href="https://colab.research.google.com/github/KatreenGhobrial/RepoCloudComputing/blob/main/Tirgulim/Tirgul1/Targil1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !ls "/content/drive/My Drive/Colab Notebooks"

# %%
import numpy as np
from matplotlib import pyplot as plt

y = np.random.randn(100)
x = [x for x in range(len(y))]

plt.plot(x, y, '-')
plt.fill_between(x, y, 200, where = (y > 195), facecolor='g', alpha=0.6)

plt.title("Sample Plot")
plt.show()

# %%
name = 'Cloud course'#@param {type:"string"}
print(name)


#@title Date fields
date_input = '2019-06-03' #@param {type:"date"}
print(date_input)

# %%
#@title Default title text
# %%html
<style>
body {
  background-color: #f2bcca;
}
</style>
color = 'blue' #@param ["red", "green", "blue"] print(color)
<svg xmlns="https://www.w3.org/2000/svg" viewBox="0 0 600 400" width="400" height="400">
   <rect x="10" y="00" width="300" height="100" rx="0" style="fill:orange; stroke:black; fill-opacity:1.0" />
   <rect x="10" y="100" width="300" height="100" rx="0" style="fill:white; stroke:black; fill-opacity:1.0;" />
   <rect x="10" y="200" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0;" />
</svg>

# %%
with open('students.txt', 'r') as file:
    contents = file.read()
    print(contents)


with open('newfile.txt', 'w') as file:
    file.write('This is some example text.')

# %%
import ipywidgets as widgets
from IPython.display import display
button = widgets.Button(description="Click Me!")
output = widgets.Output()

def on_button_clicked(b):
  # Display the message within the output widget.
  with output:
    with open('/content/drive/My Drive/students.txt', 'r') as file:
      contents = file.read()
      print(contents)

button.on_click(on_button_clicked)
display(button, output)

# %%
import ipywidgets as widgets
slider = widgets.IntSlider(value=5, max=10)
display(slider)

# %%
from typing import Text


w = widgets.Dropdown(
    options=['Addition', 'Multiplication', 'Subtraction', 'Division'],
    value='Addition',
    description='Task:',
)
txt1=widgets.Text()
txt1.value="1"
display(txt1)


def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        print("changed to %s" % change['new'])
    txt1.value=w.value


w.observe(on_change)


display(w)

# %%
import IPython
from IPython.core.display import display_html
from typing import Text
from ipywidgets import widgets
from IPython.display import HTML
from google.colab.output import _publish as publish
publish.css("b {color: blue} body {background-color: #black}")
IPython.display.display_html("<b>Student List</b>", raw=True)
w = widgets.Dropdown(
    options=['Ester Peretz', 'Katreen Ghobrial', 'Liel Etinger', 'Yohad Ben Baruch'],
    value='Yohad Ben Baruch',
    description='Task:',
)
txt1=widgets.Text()
txt1.value="1"
display(txt1)




def on_change(change):


    with open('/content/drive/My Drive/students.txt', 'r') as file:
      contents = file.read()
    if change['type'] == 'change' and change['name'] == 'value':
     print()
    # print("changed to %s" % change['new'])
    txt1.value=w.value
    with open('/content/drive/My Drive/students.txt', 'w') as file:
      name = 'Lala'#@param {type:"string"}
      # file.write(name)
      file.write(name+'\n')
      print(name)
      #@title Date fields
      date_input = '2019-06-19' #@param {type:"date"}
      file.write(date_input+'\n')
      file.write(contents+'\n')
      print(date_input)
      print(contents)


w.observe(on_change)


display(w)

# %%
#@title Default title text
# %%html
<style>
body{
background-color:#f2bcca;
}
</style>
color='green'#@param["red", "green", "blue"] print(color)
<svg xmlns="https://www.w3.org/2000/svg"viewBox="0 0 600 400" width="400" height="400">
<rect x="10" y="00" width="300" height="100" rx="0" style="fill:red; stroke:black; fill-opacity:1.0" />
<rect x="10" y="100" width="300" height="100" rx="0" style="fill:green; stroke:black; fill-opacity:1.0;" />
<rect x="10" y="200" width="300" height="100" rx="0" style="fill:blue; stroke:black; fill-opacity:1.0;" />
</svg>

with open('students.txt', 'r') as file:
    contents = file.read()
    print(contents)
